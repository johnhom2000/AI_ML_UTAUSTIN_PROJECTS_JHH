# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Business Context

# %% [markdown]
# The healthcare industry is rapidly evolving, with professionals facing increasing challenges in managing vast volumes of medical data while delivering accurate and timely diagnoses. The need for quick access to comprehensive, reliable, and up-to-date medical knowledge is critical for improving patient outcomes and ensuring informed decision-making in a fast-paced environment.
#
# Healthcare professionals often encounter information overload, struggling to sift through extensive research and data to create accurate diagnoses and treatment plans. This challenge is amplified by the need for efficiency, particularly in emergencies, where time-sensitive decisions are vital. Furthermore, access to trusted, current medical information from renowned manuals and research papers is essential for maintaining high standards of care.
#
# To address these challenges, healthcare centers can focus on integrating systems that streamline access to medical knowledge, provide tools to support quick decision-making, and enhance efficiency. Leveraging centralized knowledge platforms and ensuring healthcare providers have continuous access to reliable resources can significantly improve patient care and operational effectiveness.

# %% [markdown]
# **Common Questions to Answer**
#
# **1. Diagnostic Assistance**: "What are the common symptoms and treatments for pulmonary embolism?"
#
# **2. Drug Information**: "Can you provide the trade names of medications used for treating hypertension?"
#
# **3. Treatment Plans**: "What are the first-line options and alternatives for managing rheumatoid arthritis?"
#
# **4. Specialty Knowledge**: "What are the diagnostic steps for suspected endocrine disorders?"
#
# **5. Critical Care Protocols**: "What is the protocol for managing sepsis in a critical care unit?"

# %% [markdown]
# ### Objective

# %% [markdown]
# As an AI specialist, your task is to develop a RAG-based AI solution using renowned medical manuals to address healthcare challenges. The objective is to **understand** issues like information overload, **apply** AI techniques to streamline decision-making, **analyze** its impact on diagnostics and patient outcomes, **evaluate** its potential to standardize care practices, and **create** a functional prototype demonstrating its feasibility and effectiveness.

# %% [markdown]
# ### Data Description

# %% [markdown]
# The **Merck Manuals** are medical references published by the American pharmaceutical company Merck & Co., that cover a wide range of medical topics, including disorders, tests, diagnoses, and drugs. The manuals have been published since 1899, when Merck & Co. was still a subsidiary of the German company Merck.
#
# The manual is provided as a PDF with over 4,000 pages divided into 23 sections.

# %% [markdown]
# ## Installing and Importing Necessary Libraries and Dependencies

# %%
# Installation for GPU llama-cpp-python
# uncomment and run the following code in case GPU is being used
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python==0.1.85 --force-reinstall --no-cache-dir -q

# Installation for CPU llama-cpp-python
# uncomment and run the following code in case GPU is not being used
# !CMAKE_ARGS="-DLLAMA_CUBLAS=off" FORCE_CMAKE=1 pip install llama-cpp-python==0.1.85 --force-reinstall --no-cache-dir -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 126.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 202.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 119.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 277.5 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.1 which is incompatible.
# ...

# %%
# For installing the libraries & downloading models from HF Hub
# !pip install huggingface_hub==0.23.2 pandas==1.5.3 tiktoken==0.6.0 pymupdf==1.25.1 langchain==0.1.1 langchain-community==0.0.13 chromadb==0.4.22 sentence-transformers==2.3.1 numpy==1.25.2 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.7 MB/s eta 0:00:00
# ...

# %%
#Libraries for processing dataframes,text
import json,os
import tiktoken
import pandas as pd

#Libraries for Loading Data, Chunking, Embedding, and Vector Databases
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain_community.vectorstores import Chroma

#Libraries for downloading and loading the llm
from huggingface_hub import hf_hub_download
from llama_cpp import Llama

# %% [markdown]
# ## Question Answering using LLM

# %% [markdown]
# #### Downloading and Loading the model

# %%
model_name_or_path = "TheBloke/Mistral-7B-Instruct-v0.2-GGUF"
model_basename = "mistral-7b-instruct-v0.2.Q6_K.gguf"

# %%
model_path = hf_hub_download(
    repo_id= model_name_or_path,
    filename= model_basename
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# mistral-7b-instruct-v0.2.Q6_K.gguf:   0%|          | 0.00/5.94G [00:00<?, ?B/s]

# %%
# GPU Connect
llm = Llama(
    model_path=model_path,
    n_ctx=4000,
    n_gpu_layers=38,
    n_batch=512
)
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %% [markdown]
# #### Response

# %%
def response(query,max_tokens=128,temperature=0,top_p=0.95,top_k=50):
    model_output = llm(
      prompt=query,
      max_tokens=max_tokens,
      temperature=temperature,
      top_p=top_p,
      top_k=top_k
    )

    return model_output['choices'][0]['text']

# %%
response("What treatment options are available for managing hypertension?")
# Out:
# '\n\nHypertension, or high blood pressure, is a common condition that can increase the risk of various health problems such as heart disease, stroke, and kidney damage. The good news is that there are several effective treatment options available to help manage hypertension and reduce the risk of complications. Here are some of the most commonly used treatments:\n\n1. Lifestyle modifications: Making lifestyle changes is often the first line of defense against hypertension. This may include eating a healthy diet rich in fruits, vegetables, whole grains, and lean proteins; limiting sodium intake; getting regular physical activity'

# %% [markdown]
# **Observations:**
#
# The response seems to be cut off, likely because of the max_tokens limit set to 128 in the response function. It provides relevant information but doesn't cover the full scope of treatment options.

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
user_input = "What is the protocol for managing sepsis in a critical care unit?"
response(user_input)
# Out:
# Llama.generate: prefix-match hit
# '\n\nSepsis is a life-threatening condition that can arise from an infection, and it requires prompt recognition and aggressive management in a critical care unit. The following are general steps for managing sepsis in a critical care unit:\n\n1. Early recognition: Recognize the signs and symptoms of sepsis early and initiate treatment as soon as possible. Sepsis can present with various clinical features, including fever or hypothermia, tachycardia or bradycardia, altered mental status, respiratory distress, and lactic acidosis.\n2. Resusc'

# %% [markdown]
# **Observations:**
#
# The response discusses early recognition and resuscitation as part of the protocol. Similar to the previous query, the response seems to be cut off, likely due to the max_tokens limit in the response function. It provides a good start but doesn't cover the entire protocol.

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
user_input_2 = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"
response(user_input_2)
# Out:
# Llama.generate: prefix-match hit
# '\n\nAppendicitis is a medical condition characterized by inflammation of the appendix, a small tube-shaped organ located in the lower right side of the abdomen. The symptoms of appendicitis can vary from person to person, but some common signs include:\n\n1. Abdominal pain: The pain may start as a mild discomfort around the navel or in the lower right abdomen, which then gradually moves to the right lower quadrant and becomes more severe over time. The pain may be constant or intermittent and is often worsened by movement, coughing, or deep breathing'

# %% [markdown]
# **Observations:**
#
# The query is about appendicitis, the response lists common symptoms and begins to discuss treatment. As with the previous queries, the response seems to be cut off, likely due to the max_tokens limit in the response function.

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
user_input_3 = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
response(user_input_3)
# Out:
# Llama.generate: prefix-match hit
# "\n\nSudden patchy hair loss, also known as alopecia areata, is a common autoimmune disorder that affects the hair follicles. It can result in round or oval bald patches on the scalp, but it can also occur on other parts of the body such as the beard area, eyebrows, or eyelashes.\n\nThe exact cause of alopecia areata is not known, but it's believed to be related to a problem with the immune system. Some possible triggers for this condition include stress, genetics, viral infections, and certain medications."

# %% [markdown]
# **Observations:**
#
# The query is about sudden patchy hair loss, the response defines the condition (alopecia areata) and discusses its possible causes. As with the previous queries, the response seems to be cut off, likely due to the max_tokens limit in the response function, and does not fully cover the effective treatments.

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
user_input_4 = "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"
response(user_input_4)
# Out:
# Llama.generate: prefix-match hit
# "\n\nA person who has sustained a physical injury to brain tissue, also known as a traumatic brain injury (TBI), may require various treatments depending on the severity and location of the injury. Here are some common treatments recommended for TBIs:\n\n1. Emergency care: The first priority is to ensure the person's airway is clear, they are breathing, and their heart is beating normally. In severe cases, emergency surgery may be required to remove hematomas or other obstructions.\n2. Medications: Depending on the symptoms, medications may be prescribed to manage conditions such as"

# %% [markdown]
# **Observations:**
#
#  The query is about treatments for brain tissue injury, the response discusses emergency care, medications, and rehabilitation therapy. As with the previous queries, the response seems to be cut off, likely due to the max_tokens limit in the response function, and does not fully cover the recommended treatments.

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
user_input_5 = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"
response(user_input_5)
# Out:
# Llama.generate: prefix-match hit
# "\n\nFirst and foremost, if you suspect that someone has fractured their leg while hiking, it's essential to ensure their safety and prevent further injury. Here are some necessary precautions:\n\n1. Keep the person calm and still: Encourage them to remain as still as possible to minimize pain and prevent worsening the injury.\n2. Assess the situation: Check for any signs of shock, such as pale skin, rapid heartbeat, or shallow breathing. If you notice these symptoms, seek medical help immediately.\n3. Immobilize the leg: Use a splint, sl"

# %% [markdown]
# **Observations:**
#
#  The query is about a fractured leg, the response discusses initial precautions such as keeping the person calm and immobilizing the leg. As with the previous queries, the response seems to be cut off, likely due to the max_tokens limit in the response function, and does not fully cover the treatment steps and recovery considerations.

# %% [markdown]
# ## Question Answering using LLM with Prompt Engineering

# %%
system_prompt = "You are a helpful medical assistant. Provide concise and informative answers based on your medical knowledge."

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
user_input = system_prompt+"\n"+ "What is the protocol for managing sepsis in a critical care unit?"
response(user_input,temperature=0.5)
# Out:
# Llama.generate: prefix-match hit
# '\nSepsis is a life-threatening condition caused by a dysregulated response to infection. In a critical care unit, managing sepsis involves several key steps:\n1. Early recognition and diagnosis: Identify sepsis suspects based on clinical suspicion, laboratory results (such as white blood cell count, lactate level, and inflammatory markers), and vital signs. Use sepsis scoring systems like the Sequential Organ Failure Assessment (SOFA) score or Quick Sequential Organ Failure Assessment (qSOFA) to help with diagnosis.\n2. Immediate'

# %% [markdown]
# **Observations:**
#
#  The query is about managing sepsis with prompt engineering, the response discussed early recognition, diagnosis, and fluid resuscitation as part of the protocol. While the system prompt seems to have influenced the tone and focus, the response was still cut off, similar to the previous observations. This is likely still due to the max_tokens limit in the response function.

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
user_input = system_prompt+"\n"+ "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"
response(user_input,max_tokens=512)
# Out:
# Llama.generate: prefix-match hit
# ...

# %% [markdown]
# **Observations:**
#
# The query is about appendicitis with prompt engineering, the response listed common symptoms and discussed that it cannot be cured with medicine alone and requires surgical intervention. This time the response was not cut off, likely due to increasing the max_tokens limit to 512.

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
user_input = system_prompt+"\n"+ "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
response(user_input,temperature=0.7,max_tokens=512)
# Out:
# Llama.generate: prefix-match hit
# ...

# %% [markdown]
# **Observations:**
#
# The query is about sudden patchy hair loss with prompt engineering, the response defined the condition (alopecia areata) and discussed its possible causes. The response was not cut off this time, likely due to increasing the max_tokens limit to 512, and it covered effective treatments in more detail due to temperature value change.

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
user_input = system_prompt+"\n"+ "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"
response(user_input,top_k=75,temperature=0.7,max_tokens=512)
# Out:
# Llama.generate: prefix-match hit
# ...

# %% [markdown]
# **Observations:**
#
# a) Temperature=0.7: Introduced moderate creativity, making the output varied for brain injury.
#
# b) top_k=75: Expands the range of possible next tokens, which promoted diversity in the treatment results.
#
# c) max_tokens=512: Gives the model room for a comprehensive, paragraph-level response.

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
user_input = system_prompt+"\n"+ "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"
response(user_input,top_p=.97,temperature=0.3,max_tokens=512)
# Out:
# Llama.generate: prefix-match hit
# ...

# %% [markdown]
# **Observations:**
#
# a) temperature=0.3: The output is more focused and deterministic, avoiding unnecessary speculation.
#
# b) top_p=0.97: Allowed the model to consider a reasonably diverse set of tokens while still grounding the response.
#
# c) max_tokens=512: Gave the model enough runway to return a well-rounded answer with clinical detail.

# %% [markdown]
# ## Data Preparation for RAG

# %%
#Libraries for processing dataframes,text
import json,os
import tiktoken
import pandas as pd

#Libraries for Loading Data, Chunking, Embedding, and Vector Databases
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain_community.vectorstores import Chroma

# %% [markdown]
# ### Loading the Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
manual_pdf_path = "/content/drive/MyDrive/Colab Notebooks/NLP/medical_diagnosis_manual.pdf"

# %%
pdf_loader = PyMuPDFLoader(manual_pdf_path)

# %%
manual = pdf_loader.load()

# %% [markdown]
# ### Data Overview

# %% [markdown]
# #### Checking the first 5 pages

# %%
for i in range(5):
    print(f"Page Number : {i+1}",end="\n")
    print(manual[i].page_content,end="\n")
# Out:
# Page Number : 1
# johnhenryhom@gmail.com
# CT58BDIO0Z
# ant for personal use by johnhenryhom@g
# shing the contents in part or full is liable
#
# Page Number : 2
# johnhenryhom@gmail.com
# CT58BDIO0Z
# This file is meant for personal use by johnhenryhom@gmail.com only.
# Sharing or publishing the contents in part or full is liable for legal action.
#
# Page Number : 3
# Table of Contents
# 1
# Front    ................................................................................................................................................................................................................
# 1
# Cover    .......................................................................................................................................................................................................
# 2
# ...

# %% [markdown]
# #### Checking the number of pages

# %%
len(manual)
# Out:
# 4114

# %% [markdown]
# ### Data Chunking

# %%
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    encoding_name='cl100k_base',
    chunk_size=1024, # the chunk size
    chunk_overlap=100 # the chunk overlap is around 10% of chunk size being defined.
)

# %%
document_chunks = pdf_loader.load_and_split(text_splitter)

# %%
len(document_chunks)
# Out:
# 4533

# %%
document_chunks[0].page_content
# Out:
# 'johnhenryhom@gmail.com\nCT58BDIO0Z\nant for personal use by johnhenryhom@g\nshing the contents in part or full is liable'

# %%
document_chunks[2].page_content
# Out:
# "Table of Contents\n1\nFront    ................................................................................................................................................................................................................\n1\nCover    .......................................................................................................................................................................................................\n2\nFront Matter    ...........................................................................................................................................................................................\n53\n1 - Nutritional Disorders    ...............................................................................................................................................................\n53\nChapter 1. Nutrition: General Considerations    .........................................................................................
# ...

# %%
document_chunks[3].page_content
# Out:
# '491\nChapter 44. Foot & Ankle Disorders    .....................................................................................................................................\n502\nChapter 45. Tumors of Bones & Joints    ...............................................................................................................................\n510\n5 - Ear, Nose, Throat & Dental Disorders    ..................................................................................................................\n510\nChapter 46. Approach to the Patient With Ear Problems    ...........................................................................................\n523\nChapter 47. Hearing Loss    .........................................................................................................................................................\n535\nChapter 48. Inner Ear Disorders    .................................................................................................
# ...

# %% [markdown]
# ### Embedding

# %%
embedding_model = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2") # Code to define the model name
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
embedding_1 = embedding_model.embed_query(document_chunks[0].page_content)
embedding_2 = embedding_model.embed_query(document_chunks[1].page_content)

# %%
print("Dimension of the embedding vector ",len(embedding_1))
len(embedding_1)==len(embedding_2)
# Out:
# Dimension of the embedding vector  384
# True

# %%
embedding_1,embedding_2
# Out:
# ([-0.0930410623550415,
#   0.1136670783162117,
#   0.047095268964767456,
#   -0.03909687697887421,
#   0.06286538392305374,
#   -0.016577545553445816,
#   0.0868285670876503,
#   0.043479952961206436,
#   -0.03345777839422226,
#   0.008025527000427246,
#   0.06800954788923264,
#   0.003825525287538767,
#   -0.0017798120388761163,
#   -0.0373757928609848,
#   -0.061051145195961,
#   -0.04855707660317421,
#   -0.04706507548689842,
#   -0.014139242470264435,
#   -0.057695481926202774,
#   -0.004214771091938019,
#   -0.004019870888441801,
#   0.0050926730036735535,
#   -0.015578795224428177,
#   -0.06147928163409233,
#   -0.03448277339339256,
#   0.07619930803775787,
#   -0.06551596522331238,
#   0.04627588391304016,
#   -0.001860388438217342,
#   -0.06284772604703903,
#   0.0312332846224308,
#   0.012093812227249146,
#   0.05753251537680626,
#   -0.03867916762828827,
#   0.032570626586675644,
#   0.027135737240314484,
#   -0.0794854685664177,
#   -0.07892511785030365,
# ...

# %% [markdown]
# ### Vector Database

# %%
# Creating Output Directory
out_dir = 'medical_db'

if not os.path.exists(out_dir):
  os.makedirs(out_dir)

# %%
vectorstore = Chroma.from_documents(
    document_chunks,
    embedding_model,
    persist_directory=out_dir
)

# %%
vectorstore = Chroma(persist_directory=out_dir,embedding_function=embedding_model)

# %%
vectorstore.embeddings
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False})
#   (2): Normalize()
# ), model_name='all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False)

# %%
vectorstore.similarity_search("What are the common symptoms and treatments for pulmonary embolism?",k=3)
# Out:
# [Document(page_content="Chapter 194. Pulmonary Embolism\nIntroduction\nPulmonary embolism (PE) is the occlusion of ≥ 1 pulmonary arteries by thrombi that originate\nelsewhere, typically in the large veins of the lower extremities or pelvis. Risk factors are\nconditions that impair venous return, conditions that cause endothelial injury or dysfunction,\nand underlying hypercoagulable states. Symptoms are nonspecific and include dyspnea,\npleuritic chest pain, cough, and, in severe cases, syncope or cardiorespiratory arrest. Signs are\nalso nonspecific and may include tachypnea, tachycardia, hypotension, and a loud pulmonic\ncomponent of the 2nd heart sound. Diagnosis is based on a CT angiogram, ventilation/perfusion\nscan, or a pulmonary arteriogram. Treatment is with anticoagulants and, sometimes, clot\ndissolution with thrombolytics or surgical removal. Preventive measures include anticoagulants\nand sometimes insertion of an inferior vena caval filter.\nPE affects an estimated 117 
# ...

# %% [markdown]
# ### Retriever

# %%
retriever = vectorstore.as_retriever(
    search_type='similarity',
    search_kwargs={'k': 3}
)

# %%
rel_docs = retriever.get_relevant_documents("What are the common symptoms and treatments for pulmonary embolism?")
rel_docs
# Out:
# [Document(page_content="Chapter 194. Pulmonary Embolism\nIntroduction\nPulmonary embolism (PE) is the occlusion of ≥ 1 pulmonary arteries by thrombi that originate\nelsewhere, typically in the large veins of the lower extremities or pelvis. Risk factors are\nconditions that impair venous return, conditions that cause endothelial injury or dysfunction,\nand underlying hypercoagulable states. Symptoms are nonspecific and include dyspnea,\npleuritic chest pain, cough, and, in severe cases, syncope or cardiorespiratory arrest. Signs are\nalso nonspecific and may include tachypnea, tachycardia, hypotension, and a loud pulmonic\ncomponent of the 2nd heart sound. Diagnosis is based on a CT angiogram, ventilation/perfusion\nscan, or a pulmonary arteriogram. Treatment is with anticoagulants and, sometimes, clot\ndissolution with thrombolytics or surgical removal. Preventive measures include anticoagulants\nand sometimes insertion of an inferior vena caval filter.\nPE affects an estimated 117 
# ...

# %%
model_output = llm(
      "What are the common symptoms and treatments for pulmonary embolism?",
      max_tokens=512,
      temperature=0.7,
    )
# Out:
# Llama.generate: prefix-match hit

# %%
model_output['choices'][0]['text']
# Out:
# "\n\nPulmonary embolism (PE) is a serious condition that occurs when a blood clot or other material blocks an artery in your lungs. This can reduce or completely block blood flow to the affected lung, leading to decreased oxygen levels in the body and potentially life-threatening complications.\n\nSymptoms of pulmonary embolism may include:\n\n1. Shortness of breath: You may feel like you're unable to get enough air or that you're breathing too hard for the level of activity you're doing.\n2. Chest pain: This can be sharp, stabbing pain or a feeling of pressure in your chest. It may worsen when you take deep breaths or cough.\n3. Rapid heart rate: Your heart may beat faster than usual, which can make you feel anxious or nervous.\n4. Coughing up blood: In some cases, you may cough up blood or pink, frothy sputum.\n5. Swelling in the legs or arms: If the clot originated in a deep vein in your leg (deep vein thrombosis, or DVT), you may experience swelling, pain, or warmth in the affect
# ...

# %% [markdown]
# ### System and User Prompt Template

# %% [markdown]
# Prompts guide the model to generate accurate responses. Here, we define two parts:
#
#     1. The system message describing the assistant's role.
#     2. A user message template including context and the question.

# %%
qna_system_message = "You are a helpful medical assistant. Provide concise and informative answers based on the provided context."  #Code to define the system message

# %%
qna_user_message_template = """
Context: {context}
Question: {question}
Answer:
""" #Code to define the user message

# %% [markdown]
# ### Response Function

# %%
def generate_rag_response(user_input,k=3,max_tokens=128,temperature=0,top_p=0.95,top_k=50):
    global qna_system_message,qna_user_message_template
    # Retrieve relevant document chunks
    relevant_document_chunks = retriever.get_relevant_documents(query=user_input,k=k)
    context_list = [d.page_content for d in relevant_document_chunks]

    # Joins chunks into one long context string.
    #Trims it to ~3000 characters to avoid token overflow.
    context_for_query = ". ".join(context_list)
    context_for_query = context_for_query[:3000]


    user_message = qna_user_message_template.replace('{context}', context_for_query)
    user_message = user_message.replace('{question}', user_input)

    prompt = qna_system_message + '\n' + user_message

    # Generate the response
    try:
        response = llm(
                  prompt=prompt,
                  max_tokens=max_tokens,
                  temperature=temperature,
                  top_p=top_p,
                  top_k=top_k
                  )

        # Extract and print the model's response
        response = response['choices'][0]['text'].strip()
    except Exception as e:
        response = f'Sorry, I encountered the following error: \n {e}'

    return response

# %% [markdown]
# ## Question Answering using RAG

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
user_input = "What is the protocol for managing sepsis in a critical care unit?"
generate_rag_response(user_input, top_k=20)
# Out:
# Llama.generate: prefix-match hit
# 'Sepsis is a life-threatening condition that requires prompt recognition and intervention. In a critical care unit, the following steps are typically taken to manage sepsis:\n1. Early recognition: Monitor vital signs, laboratory values, and clinical symptoms closely for signs of infection and sepsis.\n2. Fluid resuscitation: Administer intravenous fluids to maintain adequate blood pressure and organ perfusion.\n3. Antibiotics: Start broad-spectrum antibiotics as soon as possible based on the suspected source of infection.\n4. Source control: Identify and address the source'

# %% [markdown]
# **Observations:**
#
# The query is about managing sepsis using the RAG system, the response discusses early recognition, fluid resuscitation, antibiotics, and source control as part of the protocol. The response seems to be cut off, likely due to the max_tokens limit in the generate_rag_response function.

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
user_input_2 = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"
generate_rag_response(user_input_2, top_k=20)
# Out:
# Llama.generate: prefix-match hit
# "The common symptoms of appendicitis include epigastric or periumbilical pain followed by brief nausea, vomiting, and anorexia, which later shifts to the right lower quadrant. Pain increases with cough and motion. Classic signs are right lower quadrant direct and rebound tenderness located at McBurney's point. Additional signs include Rovsing sign, psoas sign, or obturator sign. Low-grade fever is common. However, these classic findings appear in less than 50% of patients, and many variations of symptoms and signs occur.\nAppendic"

# %% [markdown]
# **Observations:**
#
# The query is about appendicitis using the RAG system, the response lists common symptoms and begins to discuss treatment. Similar to the previous observation, the response seems to be cut off, likely due to the max_tokens limit in the generate_rag_response function.

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
user_input_2 = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
generate_rag_response(user_input_2, top_k=20)
# Out:
# Llama.generate: prefix-match hit
# 'Sudden patchy hair loss, also known as alopecia areata, is a common condition characterized by round or oval bald patches on the scalp. The exact cause of alopecia areata is unknown but believed to involve an autoimmune response that attacks hair follicles.\nEffective treatments for addressing sudden patchy hair loss include:\n1. Topical corticosteroids: These medications can be applied directly to the affected area to reduce inflammation and promote hair regrowth.\n2. Intralesional corticosteroid injections: Corticosteroids can also'

# %% [markdown]
# **Observations:**
#
# The query is about sudden patchy hair loss using the RAG system, the response defined the condition (alopecia areata) and discussed its possible causes. It also listed some effective treatments. The response was cut off this time, , likely due to the max_tokens limit in the generate_rag_response function.

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
user_input_2 = "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"
generate_rag_response(user_input_2, top_k=20)
# Out:
# Llama.generate: prefix-match hit
# "1. For patients with reversible brain damage, supportive care such as oxygen therapy, ventilation, and medication to manage symptoms like seizures, increased intracranial pressure, or abnormal heart rhythms may be necessary. Rehabilitation therapies including speech, occupational, and physical therapy can help improve function and independence.\n2. For patients with irreversible brain damage, such as those diagnosed with brain death, all supporting treatments are ended, and the diagnosis is equivalent to the person's death. No one who meets criteria for brain death recovers.\n3. In cases of less severe brain"

# %% [markdown]
# **Observations:**
#
# The query is about treatments for brain tissue injury using the RAG system, the response discusses supportive care, rehabilitation therapies, and surgical interventions. The response appears to be cut off, likely due to the max_tokens limit in the generate_rag_response function.

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
user_input_2 = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"
generate_rag_response(user_input_2, top_k=20)
# Out:
# Llama.generate: prefix-match hit
# 'For a person who has fractured their leg during a hiking trip, the following precautions and treatment steps should be taken:\n1. Assess the severity of the injury and check for any signs of shock or other life-threatening conditions. If necessary, call for emergency medical assistance.\n2. Immobilize the injured leg using a splint or sling to prevent further injury and decrease pain. This can be done with a nonrigid or noncircumferential device to avoid causing additional damage to soft tissues.\n3. Apply RICE (rest, ice, compression, elevation'

# %% [markdown]
# **Observations:**
#
# The query is about a fractured leg using the RAG system, the response discusses initial precautions such as keeping the person calm and immobilizing the leg. As with the previous queries, the response seemed to be cut off, likely due to the max_tokens limit in the generate_rag_response function.

# %% [markdown]
# ### Fine-tuning

# %% [markdown]
# #### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
user_input = "What is the protocol for managing sepsis in a critical care unit?"
generate_rag_response(user_input,temperature=0.5)
# Out:
# Llama.generate: prefix-match hit
# "Sepsis is a life-threatening condition that requires prompt recognition and aggressive management in a critical care unit. The following steps are typically taken to manage sepsis in a critical care setting:\n1. Early recognition: Septic patients should be identified early based on clinical signs, laboratory results, and vital sign abnormalities such as fever, tachycardia, respiratory distress, and low blood pressure.\n2. Initial assessment and resuscitation: The patient's airway, breathing, circulation, and neurologic status should be assessed and addressed accordingly. This may include providing oxygen therapy"

# %% [markdown]
# **Observations:**
#
# Setting the temperature parameter to 0.5 introduced a moderate level of randomness in the generated output. Compared to a temperature of 0 (which is completely deterministic), a temperature of 0.5 allowed the model to choose tokens that are not necessarily the most probable, leading to more varied and potentially more creative response.

# %% [markdown]
# #### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
user_input_2 = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"
generate_rag_response(user_input_2,max_tokens=512)
# Out:
# Llama.generate: prefix-match hit
# ...

# %% [markdown]
# **Observations:**
#
# The query about appendicitis with the fine-tuned RAG system, increasing the max_tokens limit to 512 prevented the response from being cut off and provided a more details symptoms and treatment.

# %% [markdown]
# #### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
user_input_2 = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
generate_rag_response(user_input_2,k=3,max_tokens=512,temperature=0.3,top_p=0.97,top_k=5)
# Out:
# Llama.generate: prefix-match hit
# ...

# %% [markdown]
# **Observations:**
#
# a) The parameters balances focused generation (low temperature) with flexibility in token choice (moderate top-p), provided detailed, grounded answers.
#
# b) The model delivers a medically aligned, structured answer that includes a brief explanation of the condition (alopecia areata) and multiple evidence-based treatments, like topical corticosteroids, intralesional injections, and oral corticosteroids.
#
# c) The token size increase has also helpled in better explanation.

# %% [markdown]
# #### Query 4: What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
user_input_2 = "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"
generate_rag_response(user_input_2,temperature=0.5, max_tokens=1024)
# Out:
# Llama.generate: prefix-match hit
# ...

# %% [markdown]
# **Observations**
#
# a) The question is long-form yet clear, targeting a specific medical issue—traumatic brain injury.
#
# b) It strikes a balance between diagnostic inquiry ("causes") and intervention request ("treatments or solutions"), guiding the model toward a comprehensive answer.
#
# c) The response is structured in a numbered list format, making it digestible and actionable.
#
# d) It covers both acute (e.g., supportive care, surgical options) and chronic phases (e.g., rehabilitation, cognitive therapy) of brain injury treatment, which suggests the model had high-quality context to work with.
#
# e) Inclusion of family involvement and interdisciplinary care indicates that the model is thinking holistically—not just clinically.
#
# f) The output does not show signs of hallucination and sticks to widely accepted treatment approaches—suggesting clean context and smart chunking.

# %% [markdown]
# #### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
user_input_2 = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"
generate_rag_response(user_input_2,max_tokens=1024,top_p=0.97,top_k=75)
# Out:
# Llama.generate: prefix-match hit
# ...

# %% [markdown]
# **Observations:**
#
# a) The model clearly had access to relevant and trustworthy content which is evident in how it walks through emergency management (immobilization, RICE protocol) and clinical care (e.g. opioids, surgical fixation).Rehabilitation and follow-up care are also covered.
#
# b) The answer is step-by-step, logical, and clinically sound.Mentions multiple pain relief strategies and various fixation options, showing that the context allowed for a non-one-size-fits-all response.
#
# c) Includes preventive advice tailored to hiking scenarios—evidence the retriever pulled lifestyle-specific data, not just textbook trauma guidelines.
#
# d) The parameters max_tokens, top_p and top_k values helped in high factual density with no signs of hallucination. Context-aware generation based on a diverse and coherent retrieved set.

# %% [markdown]
# ## Output Evaluation

# %% [markdown]
# Let us now use the LLM-as-a-judge method to check the quality of the RAG system on two parameters - retrieval and generation.
#
# - We are using the same Mistral model for evaluation, so basically here the llm is rating itself on how well he has performed in the task.

# %% [markdown]
# ### Defining the Evaluation Prompts

# %%
groundedness_rater_system_message  = """
You are tasked with rating AI generated answers to questions posed by users.
You will be presented a question, context used by the AI system to generate the answer and an AI generated answer to the question.
In the input, the question will begin with ###Question, the context will begin with ###Context while the AI generated answer will begin with ###Answer.

Evaluation criteria:
The task is to judge the extent to which the metric is followed by the answer.
1 - The metric is not followed at all
2 - The metric is followed only to a limited extent
3 - The metric is followed to a good extent
4 - The metric is followed mostly
5 - The metric is followed completely

Metric:
The answer should be derived only from the information presented in the context

Instructions:
1. First write down the steps that are needed to evaluate the answer as per the metric.
2. Give a step-by-step explanation if the answer adheres to the metric considering the question and context as the input.
3. Next, evaluate the extent to which the metric is followed.
4. Use the previous information to rate the answer using the evaluaton criteria and assign a score.
"""

# %%
relevance_rater_system_message = """
You are tasked with rating AI generated answers to questions posed by users.
You will be presented a question, context used by the AI system to generate the answer and an AI generated answer to the question.
In the input, the question will begin with ###Question, the context will begin with ###Context while the AI generated answer will begin with ###Answer.

Evaluation criteria:
The task is to judge the extent to which the metric is followed by the answer.
1 - The metric is not followed at all
2 - The metric is followed only to a limited extent
3 - The metric is followed to a good extent
4 - The metric is followed mostly
5 - The metric is followed completely

Metric:
Relevance measures how well the answer addresses the main aspects of the question, based on the context.
Consider whether all and only the important aspects are contained in the answer when evaluating relevance.

Instructions:
1. First write down the steps that are needed to evaluate the context as per the metric.
2. Give a step-by-step explanation if the context adheres to the metric considering the question as the input.
3. Next, evaluate the extent to which the metric is followed.
4. Use the previous information to rate the context using the evaluaton criteria and assign a score.
"""

# %%
user_message_template = """
###Question
{question}

###Context
{context}

###Answer
{answer}
"""

# %% [markdown]
# ### Defining the Evaluation Function

# %%
def generate_ground_relevance_response(user_input,k=3,max_tokens=128,temperature=0,top_p=0.95,top_k=50):
    global qna_system_message,qna_user_message_template
    # Retrieve relevant document chunks
    relevant_document_chunks = retriever.get_relevant_documents(query=user_input,k=3)
    context_list = [d.page_content for d in relevant_document_chunks]
    context_for_query = ". ".join(context_list)

    # Combine user_prompt and system_message to create the prompt
    prompt = f"""[INST]{qna_system_message}\n
                {'user'}: {qna_user_message_template.format(context=context_for_query, question=user_input)}
                [/INST]"""

    response = llm(
            prompt=prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            stop=['INST'],
            )

    answer =  response["choices"][0]["text"]

    # Combine user_prompt and system_message to create the prompt
    groundedness_prompt = f"""[INST]{groundedness_rater_system_message}\n
                {'user'}: {user_message_template.format(context=context_for_query, question=user_input, answer=answer)}
                [/INST]"""

    # Combine user_prompt and system_message to create the prompt
    relevance_prompt = f"""[INST]{relevance_rater_system_message}\n
                {'user'}: {user_message_template.format(context=context_for_query, question=user_input, answer=answer)}
                [/INST]"""

    response_1 = llm(
            prompt=groundedness_prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            stop=['INST'],
            )

    response_2 = llm(
            prompt=relevance_prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            stop=['INST'],
            )

    return response_1['choices'][0]['text'],response_2['choices'][0]['text']

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
ground,rel = generate_ground_relevance_response(user_input="What is the protocol for managing sepsis in a critical care unit?",max_tokens=350)

print(ground,end="\n\n")
print(rel)
# Out:
# RAG Prompt length (characters): 3256
# Llama.generate: prefix-match hit
# Groundedness Prompt length (characters): 2830
# Relevance Prompt length (characters): 3199
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# I would rate the answer a 3, as it is derived from the context to a good extent. The question asks about managing sepsis in a critical care unit, and the context discusses the importance of recognizing and treating infections in ICU patients, as well as providing supportive care. The answer directly addresses these points by discussing the recognition and initial resuscitation steps for sepsis management. However, it's important to note that the context does not provide specific details about
#
# ...

# %% [markdown]
# **Observations:**
#
# a) **Groundedness (3/5):** suggests the model’s response aligns partially with retrieved content but lacks deeper anchoring.
#
# b) **Relevance (4/5):** highlights that the generated output was directionally on target, but omitted important clinical details. This subtle distinction is crucial for medical domains where completeness matters as much as accuracy.

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
ground,rel = generate_ground_relevance_response(user_input="What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?",max_tokens=512)

print(ground,end="\n\n")
print(rel)
# Out:
# RAG Prompt length (characters): 3335
# Llama.generate: prefix-match hit
# Groundedness Prompt length (characters): 2909
# Relevance Prompt length (characters): 3278
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Rating: 5
#
# Explanation: The AI generated answer is completely derived from the context as it accurately summarizes the symptoms and signs of appendicitis mentioned in the provided text.
#
# Rating: 5
#
# Explanation: The AI-generated answer directly addresses the key aspects of the question by listing the common symptoms of appendicitis and acknowledging that it cannot be cured via medicine but requires surgical treatment. The answer also provides additional context about the signs associated with appendicitis, which further enhances its relevance to the question.

# %% [markdown]
# **Observations:**
#
# a) **Groundedness (5/5):** The fact that the generated answer fully aligns with the retrieved context suggests retriever is fetching highly relevant content, and prompt construction is being preserved during generation.
#
# b) **Relevance (5/5):** The response answer the user’s query directly, but it goes a step further by enriching it with contextual insight, demonstrating both high retrieval quality and a model capable of thoughtful summarization.

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
ground,rel = generate_ground_relevance_response(user_input="What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?",max_tokens=1024,top_p=.97)

print(ground,end="\n\n")
print(rel)
# Out:
# RAG Prompt length (characters): 3378
# Llama.generate: prefix-match hit
# Groundedness Prompt length (characters): 2952
# Relevance Prompt length (characters): 3321
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Rating: 5 - The Answer is derived from Context completely.
#
# Explanation: The user's question asks about effective treatments for sudden patchy hair loss, specifically in the context of alopecia areata. The context provided in the table discusses various treatments for alopecia areata, including topical and intralesional corticosteroids and topical immunotherapies. Therefore, the answer directly addresses the user's question by listing the specific
#
# Rating: 5
#
# ...

# %% [markdown]
# **Observations:**
#
# a) **Groundedness (5/5):** The model’s response closely mirrors the retrieved context, listing treatments for alopecia areata that match specific references from your underlying documents. This indicates retriever and chunking logic are surfacing precisely what the model needs to answer fully and accurately.
#
# b) **Relevance (5/5):** The answer not only addresses the main thrust of the question (treatments), but also adds diagnostic clarity by identifying alopecia areata as the condition.

# %% [markdown]
# ### Query 4: What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
ground,rel = generate_ground_relevance_response(user_input="What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?",k=5, max_tokens=512,temperature=0.5)

print(ground,end="\n\n")
print(rel)
# Out:
# RAG Prompt length (characters): 3354
# Llama.generate: prefix-match hit
# Groundedness Prompt length (characters): 2928
# Relevance Prompt length (characters): 3297
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Rating: 3 - The AI-generated answer is derived from the context to a good extent. The context mentions the possibility of temporary or permanent impairment of brain function due to a physical injury, and the answer correctly identifies supportive care, rehabilitation therapies, and medications as potential treatments for such a condition. However, the answer does not directly reference any specific details from the context, so it is not a complete match.
#
# Rating: 4
#
# ...

# %% [markdown]
# **Observations:**
#
# a) **Groundedness (3/5):** The model pulls general, medically appropriate treatments from the context—supportive care, rehabilitation, medications.
# However, it misses explicit anchoring to details in the retrieved chunks.
#
# b) **Relevance (4/5):** The answer aligns well with the core query and is medically sound. Some clinical granularity is missing—like surgical options or therapy stratification by injury type.

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
ground,rel = generate_ground_relevance_response(user_input="What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?",k=5, max_tokens=500)

print(ground,end="\n\n")
print(rel)
# Out:
# RAG Prompt length (characters): 3367
# Llama.generate: prefix-match hit
# Groundedness Prompt length (characters): 2941
# Relevance Prompt length (characters): 3310
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Rating: 4 - The AI-generated answer is derived from the context mostly.
#
# Explanation: The question asks for necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip. The context provides information on various injuries that can occur during such an incident, including arterial injuries, nerve injuries, and fractures. It also mentions the importance of immobilization, RICE therapy, and seeking medical help if necessary. The
#
# Rating: 5
#
# ...

# %% [markdown]
# **Observations:**
#
# a) **Groundedness (4/5):** The generated answer largely echoes key contextual content—especially around immobilization, RICE therapy, and early assessment.
#
# b) **Relevance (5/5):** The response clearly aligns with the user’s intent, mirrors clinical priorities, and presents the treatment in a stepwise, comprehensible fashion. It is also reflective of strong prompt architecture—the model clearly understood both the scope and the tone.

# %% [markdown]
# ## Actionable Insights and Recommendations
#
# Based on the successful implementation and initial evaluation of the RAG system using the Merck Manual, here are some actionable insights and recommendations for the business:
#
# ### Key Takeaways:
#
# *   **Potential to address information overload:** The RAG system demonstrates the capability to quickly retrieve relevant information from a large medical manual based on specific queries, which can significantly help healthcare professionals in managing information overload.
# *   **Improved efficiency in accessing medical knowledge:** By providing a conversational interface to the medical manual, the system can streamline the process of accessing critical medical information, potentially leading to faster and more informed decision-making.
# *   **Foundation for diagnostic assistance:** The ability to retrieve relevant information on symptoms, treatments, and protocols lays a strong foundation for building tools that can assist in diagnostic processes.
# *   **Scalability:** The RAG approach is scalable and can potentially be extended to include other medical manuals, research papers, and internal knowledge bases to create a more comprehensive medical knowledge platform.
# *   **Potential for standardization of care:** Providing access to trusted information from renowned manuals can contribute to standardizing care practices within healthcare centers.
#
# ### Business Recommendations:
#
# 1.  **Develop a user-friendly interface:** Build an intuitive and easy-to-use interface for healthcare professionals to interact with the RAG system. This could be a web application, a mobile app, or integration into existing electronic health record (EHR) systems.
# 2.  **Expand the knowledge base:** Incorporate additional trusted medical sources, such as other manuals, clinical guidelines, and research databases, to enhance the breadth and depth of the information available to the system.
# 3.  **Integrate with clinical workflows:** Explore integrating the RAG system into existing clinical workflows to provide just-in-time information during patient consultations, diagnosis, and treatment planning.
# 4.  **Pilot testing and user feedback:** Conduct pilot testing with a group of healthcare professionals to gather feedback on the system's usability, accuracy, and effectiveness in real-world scenarios. Use this feedback to refine the system.
# 5.  **Explore advanced features:** Consider adding features such as the ability to ask follow-up questions, summarize information from multiple sources, and provide differential diagnoses based on presented symptoms.
# 6.  **Address data privacy and security:** Ensure that the system complies with all relevant data privacy and security regulations (e.g., HIPAA) when handling medical information.
# 7.  **Monitor and evaluate performance:** Continuously monitor the system's performance and gather metrics on its usage and impact on clinical outcomes.

# %% [markdown]
# <font size=6 color='blue'>Power Ahead</font>
# ___
